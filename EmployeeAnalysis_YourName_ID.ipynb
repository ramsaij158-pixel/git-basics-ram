# %% [markdown]
# <a href="https://colab.research.google.com/github/ramsaij158-pixel/git-basics-ram/blob/main/EmployeeAnalysis_YourName_ID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import random
import pandas as pd

conn = sqlite3.connect('employees.db')
cursor = conn.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS employees (
    emp_id INTEGER PRIMARY KEY,
    name TEXT,
    department TEXT,
    salary REAL,
    years_experience INTEGER,
    performance_score REAL
)
''')

departments = ['Engineering', 'Sales', 'Marketing', 'HR', 'Finance']

for i in range(1, 41):
    name = f'Employee_{i}'
    department = random.choice(departments)
    salary = random.randint(50000, 150000)
    years_experience = random.randint(1, 15)
    performance_score = round(random.uniform(1.0, 5.0), 2)

    cursor.execute('''
    INSERT INTO employees (emp_id, name, department, salary, years_experience, performance_score)
    VALUES (?, ?, ?, ?, ?, ?)
    ''', (i, name, department, salary, years_experience, performance_score))

conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_181/2230480463.py in <cell line: 0>()
#      26     performance_score = round(random.uniform(1.0, 5.0), 2)
#      27
# ---> 28     cursor.execute('''
#      29     INSERT INTO employees (emp_id, name, department, salary, years_experience, performance_score)
#      30     VALUES (?, ?, ?, ?, ?, ?)
#
# OperationalError: database is locked

# %%
query1 = '''
SELECT name, department, salary, performance_score
FROM employees
WHERE performance_score >= 4.0 AND years_experience >= 3
ORDER BY performance_score DESC
LIMIT 15
'''

df1 = pd.read_sql_query(query1, conn)
df1
# Out:
#           name   department    salary  performance_score
# 0  Employee_17      Finance  104914.0               4.93
# 1  Employee_23           HR   52660.0               4.86
# 2  Employee_21    Marketing  141398.0               4.57
# 3  Employee_28    Marketing   84734.0               4.46
# 4  Employee_16        Sales   53686.0               4.45
# 5  Employee_18           HR   63026.0               4.36
# 6  Employee_25    Marketing  143200.0               4.36
# 7  Employee_20           HR  140540.0               4.16
# 8  Employee_22  Engineering   76268.0               4.05

# %%
query2 = '''
SELECT *
FROM employees
WHERE salary BETWEEN 70000 AND 110000
AND department IN ('Engineering', 'Sales')
ORDER BY department ASC, salary DESC
'''

df2 = pd.read_sql_query(query2, conn)
df2
# Out:
#    emp_id         name   department    salary  years_experience  \
# 0      15  Employee_15  Engineering  105921.0                 8
# 1       8   Employee_8  Engineering  105725.0                10
# 2      10  Employee_10  Engineering   91008.0                15
# 3      30  Employee_30  Engineering   77746.0                 2
# 4      22  Employee_22  Engineering   76268.0                 5
# 5      13  Employee_13  Engineering   70967.0                12
# 6       2   Employee_2        Sales   95947.0                 2
# 7      39  Employee_39        Sales   89424.0                 9
# 8       1   Employee_1        Sales   75300.0                11
#
#    performance_score
# 0               2.70
# 1               2.82
# 2               3.83
# 3               1.79
# 4               4.05
# 5               2.08
# 6               1.96
# 7               3.29
# 8               2.70

# %%
query3 = '''
SELECT department,
       COUNT(*) AS employee_count,
       AVG(salary) AS avg_salary
FROM employees
GROUP BY department
ORDER BY avg_salary DESC
'''

df3 = pd.read_sql_query(query3, conn)
df3
# Out:
#     department  employee_count     avg_salary
# 0    Marketing               7  120479.000000
# 1      Finance              12  106233.500000
# 2  Engineering               9  102251.777778
# 3           HR               7   98708.857143
# 4        Sales               5   89840.400000

# %%
df_all = pd.read_sql_query("SELECT * FROM employees", conn)

avg_perf = df_all.groupby('department')['performance_score'].mean()
avg_perf
# Out:
# department
# Engineering    2.984444
# Finance        2.795833
# HR             3.234286
# Marketing      3.874286
# Sales          3.164000
# Name: performance_score, dtype: float64

# %%
df_pandas_q1 = (
    df_all.loc[
        (df_all['performance_score'] >= 4.0) &
        (df_all['years_experience'] >= 3)
    ][['name', 'department', 'salary', 'performance_score']]
    .sort_values(by='performance_score', ascending=False)
    .head(15)
)

df_pandas_q1
# Out:
#            name   department    salary  performance_score
# 16  Employee_17      Finance  104914.0               4.93
# 22  Employee_23           HR   52660.0               4.86
# 20  Employee_21    Marketing  141398.0               4.57
# 27  Employee_28    Marketing   84734.0               4.46
# 15  Employee_16        Sales   53686.0               4.45
# 24  Employee_25    Marketing  143200.0               4.36
# 17  Employee_18           HR   63026.0               4.36
# 19  Employee_20           HR  140540.0               4.16
# 21  Employee_22  Engineering   76268.0               4.05

# %% [markdown]
# sql and pandas are both powerful tools used for data analysis ,pandas is cant handle the mare then 5 mb of data it is pandas can handle below 5 percent  it can data handle with the csv files, excel files of data and sql can write query it is easily interact with the large databases to data extraction ,sql is uses the less efficient memory storage and pandas is use the more memory finally pandas is useful for the csv datasate and sql is usefor the writing the queys to the databases to assign the data in a correct format ,but they differ in syntax and usage. In SQL, we use operators like =, AND, and ORDER BY to filter and sort data. In contrast, Pandas uses ==, &, and functions like .sort_values() for similar operations. SQL queries are written in a structured, declarative format, while Pandas uses Python-based, object-oriented syntax.
